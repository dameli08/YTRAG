# %% [markdown]
# ### Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="this is the main text content I am using to create RAG",
    metadata = {
        "source": "example.txt",
        "pages": 1,
        "author": "Dameli Kassym",
        "data_created": "2025-01-01"
    }
)

# %%
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Dameli Kassym', 'data_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
## create a simple txt file

import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader
from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt", 
    loader_cls = TextLoader,
    loader_kwargs={"encoding":"utf-8"},
    show_progress = False
)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader, PyMuPDFLoader

#load all the text files from directory
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob = "**/*.pdf",
    loader_cls = PyMuPDFLoader,
    show_progress=False
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\E-receipt.pdf', 'file_path': '..\\data\\pdf\\E-receipt.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Trip.com Travel Singapore Pte. Ltd.\nCompany No/GST Reg. No: 201613701E\nBooking No. 1688893809231567\nDate of Booking: 5:18 AM, October 4, 2025 (GMT+8)\nReceipt\nContact Info\nContact Name\nDAMELI KASSYM\nEmail\ndame*****ssym@nu.edu.kz\nPassenger & E-ticket No.\nDAMELI KASSYM\n999-7379002837\nFlights\nTaipei - Beijing\nAir China CA190\nOctober 30, 2025\nEconomy class\nBeijing - Astana\nAir China CA791\nOctober 31, 2025\nEconomy class\nPrice Summary\nAmount\nFare\nTaxes & fees\nDelayed Baggage Protection\n125,916.00 KZT\n54,853.00 KZT\n2,735.00 KZT\nTotal (Visa 440043***06)\n183,504.00 KZT\nThis receipt is automatically generated.\nTrip.com Travel Singapore Pte. Ltd.\n1/2'),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\E-receipt.pdf', 'file_path': '..\\data\\pdf\\E-receipt.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content='Trip.com Travel Singapore Pte. Ltd.\n2/2'),
#  Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Explanatory Note Regarding Return from Leave of Absence.pdf', 'file_path': '..\\data\\pdf\\Explanatory Note Regarding Return from Leave of Absence.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'Explanatory Note Regarding Return from Leave of Absence', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='To: Active Provost of Nazarbayev University\u200b\nFrom: Dameli Kassym, School of Sciences and Humanities \nExplanatory Note Regarding Return from Leave of Absence \nDear Provost, \nI am writing to request to return from my Leave of Absence, previously granted for the Fall \n2025 semester. I have successfully completed my international research internship in Taiwan, \nwhich took place from July 30, 2025, to early November 2025. \nDuring this internship, I worked on a collaborative research project at the National Taiwan \nUniversity. The experience has greatly enhanced my research and technical skills, deepened \nmy understanding of Machine Learning applications, and strengthened my academic \nfoundation for further studies at Nazarbayev University. \nAs the internship is now concluding, I am eager to resume my academic studies starting from \nthe Spring 2026 semester. I respectfully request permission to return from my Leave of \nAbsence and continue my coursework within the School of Sciences and Humanities. \nThank you for your attention and consideration. \nSincerely,\u200b\n Dameli Kassym\u200b\n Student ID: 202174279\u200b\n School of Sciences and Humanities, Nazarbayev University\u200b\n Date: 28.10.2025\u200b\n  \nSignature:'),
#  Document(metadata={'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'file_path': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Explanatory Note_Dameli Kassym', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='To: Active Provost of Nazarbayev University \nFrom: Dameli Kassym, School of Sciences and Humanities \n  \nExplanatory Note Regarding Leave of Absence Request \n  \nDear Provost, \nI am writing to formally explain the reason for my request to take a leave of absence for the \nFall 2025 semester. I have been accepted to participate in an international research internship in \nTaiwan, scheduled from July 30, 2025, to early December 2025. This opportunity is directly \naligned with my academic and professional goals, especially in the field of Machine Learning \nand its real-world applications. \nThe internship is part of a collaborative research project hosted at a well-regarded research \ninstitute National Taiwan University, where I will contribute to work related to the \nCrystalFormer model. This experience will provide me with valuable hands-on research \nexposure, mentorship from international experts, and skills that will significantly enrich my \ncontributions upon returning to Nazarbayev University. \nGiven the timing and nature of the internship, I would not be able to attend classes during the \nFall 2025 semester. Therefore, I respectfully request a leave of absence to fully participate in \nthis program. I remain committed to continuing my studies in the Spring 2026 semester and \nwill ensure that all academic and administrative requirements for a smooth return are fulfilled \nin advance. \nThank you for considering my request. \nSincerely, \nDameli Kassym \nStudent ID: 202174279 \nSchool of Sciences and Humanities, Nazarbayev University \nDate: 08.07.2025 \nSignature:'),
#  Document(metadata={'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'file_path': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Explanatory Note_Dameli Kassym', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content=''),
#  Document(metadata={'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'file_path': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Explanatory Note_Dameli Kassym', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}, page_content=''),
#  Document(metadata={'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'file_path': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Explanatory Note_Dameli Kassym', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 3}, page_content=''),
#  Document(metadata={'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'file_path': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Explanatory Note_Dameli Kassym', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 4}, page_content=''),
#  Document(metadata={'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'file_path': '..\\data\\pdf\\Explanatory Note_Dameli Kassym (3).pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Explanatory Note_Dameli Kassym', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 5}, page_content=''),
#  Document(metadata={'producer': 'Microsoft® Word для Microsoft 365', 'creator': 'Microsoft® Word для Microsoft 365', 'creationdate': '2025-10-23T22:24:32+08:00', 'source': '..\\data\\pdf\\IIPP_Final_Report_Dameli_Kassym.pdf', 'file_path': '..\\data\\pdf\\IIPP_Final_Report_Dameli_Kassym.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': '許家豪', 'subject': '', 'keywords': '', 'moddate': '2025-10-23T22:24:32+08:00', 'trapped': '', 'modDate': "D:20251023222432+08'00'", 'creationDate': "D:20251023222432+08'00'", 'page': 0}, page_content='2025 \nInternational Internship Pilot Program  \nin Taiwan \n \nFinal Report \n \n \n \n \n \nName：Kassym/Dameli  \nInternship Inst.：National Taiwan University (NTU) \nName of PI/Department/School：Ying Jer Kao/Department of \nPhysics/College of Science \nSubmission Date：23.10.2025'),
#  Document(metadata={'producer': 'Microsoft® Word для Microsoft 365', 'creator': 'Microsoft® Word для Microsoft 365', 'creationdate': '2025-10-23T22:24:32+08:00', 'source': '..\\data\\pdf\\IIPP_Final_Report_Dameli_Kassym.pdf', 'file_path': '..\\data\\pdf\\IIPP_Final_Report_Dameli_Kassym.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': '許家豪', 'subject': '', 'keywords': '', 'moddate': '2025-10-23T22:24:32+08:00', 'trapped': '', 'modDate': "D:20251023222432+08'00'", 'creationDate': "D:20251023222432+08'00'", 'page': 1}, page_content='Part I. Overview \n◼ What is your intention to come to Taiwan for this internship? \nI am eager to join this internship because it represents both professional and personal growth \nopportunity. Professionally, I aim to strengthen my research and programming skills in machine \nlearning for materials science. Personally, I’m excited to experience Taiwan’s culture and work with \npeople from diverse backgrounds, which I believe will enrich my perspective as a future researcher. \n◼ Please describe your gains and experience acquired from this internship. \nDuring my internship in Taiwan, I gained hands-on experience with the CrystalFormer project, \nwhere I learned how machine learning can be applied to crystal structure prediction. I became more \nskilled in data preprocessing, feature engineering, and model evaluation. I also learned how to \ncollaborate in a research group, communicate technical ideas effectively, and document results \nclearly. This internship strengthened my motivation to pursue further research at the intersection of \nAI and material science. \n◼ Please describe your life in Taiwan, how to deal with difficulties? \nMy life in Taiwan has been inspiring and full of growth. I enjoy the peaceful environment, kind people, \nand the culture of respect and collaboration. At first, I faced difficulties such as language barriers and \nadapting to new food and climate, but I dealt with them through patience, curiosity, and support from \nmy colleagues and local friends. Each challenge helped me become more independent and confident. \n◼ During the internship, what impressed you most and made you recommend the \ninternship to your friends? \nI was most impressed by how welcoming and supportive everyone was, both in the lab and outside. I \nlearned a lot not only about research but also about teamwork and cultural exchange. The kindness \nof people in Taiwan and the collaborative atmosphere made this internship a truly special experience \nthat I would recommend to my friends. \n◼ If there is any other similar chance for you to choose, would you like to \nparticipate in this program again? And why? \nSure! I would gladly participate again. The internship allowed me to work on the interesting project, \ndeepen my understanding of machine learning in materials science, and grow as a young researcher. \nThe welcoming environment, helpful mentors, and inspiring research culture in Taiwan made this \nexperience unforgettable and one I would love to repeat. \n◼ Please describe during your internship, which PI and institute have you \ncommunicated or interacted with? \nThroughout my internship, I mainly communicated with Professor Ying Jer Kao and the research \nteam at National Taiwan University. Our discussions focused on the CrystalFormer project, where I \ncontributed to data preprocessing, dataset curation, and analysis. I also interacted with another lab \nmember from Physics department to share progress updates during group meetings.'),
#  Document(metadata={'producer': 'Microsoft® Word для Microsoft 365', 'creator': 'Microsoft® Word для Microsoft 365', 'creationdate': '2025-10-23T22:24:32+08:00', 'source': '..\\data\\pdf\\IIPP_Final_Report_Dameli_Kassym.pdf', 'file_path': '..\\data\\pdf\\IIPP_Final_Report_Dameli_Kassym.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': '許家豪', 'subject': '', 'keywords': '', 'moddate': '2025-10-23T22:24:32+08:00', 'trapped': '', 'modDate': "D:20251023222432+08'00'", 'creationDate': "D:20251023222432+08'00'", 'page': 2}, page_content=''),
#  Document(metadata={'producer': 'Microsoft® Word для Microsoft 365', 'creator': 'Microsoft® Word для Microsoft 365', 'creationdate': '2025-10-23T22:24:32+08:00', 'source': '..\\data\\pdf\\IIPP_Final_Report_Dameli_Kassym.pdf', 'file_path': '..\\data\\pdf\\IIPP_Final_Report_Dameli_Kassym.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': '許家豪', 'subject': '', 'keywords': '', 'moddate': '2025-10-23T22:24:32+08:00', 'trapped': '', 'modDate': "D:20251023222432+08'00'", 'creationDate': "D:20251023222432+08'00'", 'page': 3}, page_content='Part II. Research Finding \nSubject \nDescription \nFont \nEnglish：Times New Roman \nLine height \n1.5 times \nSize \n⚫ \nTitle/ Your Research Topic: bold size 18 \n⚫ \nI, II…. ：bold size 16 \n⚫ \nA, B, …：bold size 14 \n⚫ \nOthers：size 12 \nParagraph \n⚫ \nPlease refer to the example format as below. \nChapters and \nSections \n⚫ \nI, A, 1, 1.1, 1.1.1, and so forth \nTables, \n⚫ \nFigures and tables please follow the rule, such as Fig 1, \nFig 2, Table 1, Table 2, and so forth. \n⚫ \nThe titles of figures or tables please use Times New \nRoman size 12. \nAbbreviation \n⚫ \nSuch as：Sustainable Development Goals (SDGs） \nReference\n（footnote） \n⚫ \nUse APA format, size 10 \n⚫ \nFootnote example1 \n⚫ \nNetwork resource footnote example2 \n \n \n \n \n1 Author, A. A., Author, B. B., & Author, C. C. (Year). Title of article. Title of Periodical, xx(xx), xxx-xxx. \n2 Author, A. A. (Year, Month Day). Title of post. Retrieved from http://xxx.xxx.xxx'),
#  Document(metadata={'producer': 'Microsoft® Word для Microsoft 365', 'creator': 'Microsoft® Word для Microsoft 365', 'creationdate': '2025-10-23T22:24:32+08:00', 'source': '..\\data\\pdf\\IIPP_Final_Report_Dameli_Kassym.pdf', 'file_path': '..\\data\\pdf\\IIPP_Final_Report_Dameli_Kassym.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': '許家豪', 'subject': '', 'keywords': '', 'moddate': '2025-10-23T22:24:32+08:00', 'trapped': '', 'modDate': "D:20251023222432+08'00'", 'creationDate': "D:20251023222432+08'00'", 'page': 4}, page_content='Example \n(Title/ Your Research Topic) \nI. □□□□□□□□□ \nA. OOOOOO… \n \n1. **********… \n2. **********… \n  2.1 &&&&&&&&&… \n     2.1.1 ccccccccccc… \n     2.1.2 ccccccccccc… \n  2.2 &&&&&&&&&…  \n2.3 &&&&&&&&&… \n    3. **********…. \n      3.1 &&&&&&&&&… \n3.2 &&&&&&&&&…. \n \nB.  OOOOOO… \n1. **********… \n2. **********… \n \nSince my report includes extensive coding, I decided to prepare the final version in \nGoogle Colab to ensure that no detailed code segments are missed. The Colab \nnotebook contains two separate links, each corresponding to different parts of the \nwork. Here is the link to the final report that has been done throughout the research: \n \nhttps://colab.research.google.com/drive/1zby0f3TM8WJrep_xU89Xu2G9S0KgQGzN\n?usp=sharing'),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Itinerary.pdf', 'file_path': '..\\data\\pdf\\Itinerary.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Itinerary\nBooking Information\nWe advise you print out your itinerary and take it with you to ensure your trip goes as smoothly as\npossible.\nBooking No. 1688893809231567\nTaipei - Astana\nName\nClass\nE-ticket No.\nAirline Booking\nReference\nDAMELI\xa0(First\nname)\xa0KASSYM\xa0(Last name)\nEconomy\n999-7379002837\nMJX858\nFlight Information\nTaipei - Astana\nTaipei - Beijing\nDeparture\n18:45, October 30, 2025, Taiwan Taoyuan International\nAirport T2\nArrival\n22:20, October 30, 2025, Beijing Capital International\nAirport T3\nAirline\nAir China CA190\nTransfer: Beijing | Beijing Capital International Airport T3 | 14hr 40mins\nBaggage checked through\nBeijing - Astana\nDeparture\n13:00, October 31, 2025, Beijing Capital International\nAirport T3\nArrival\n20:20, October 31, 2025, Nursultan Nazarbayev\n1'),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Itinerary.pdf', 'file_path': '..\\data\\pdf\\Itinerary.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content="International Airport T1\nAirline\nAir China CA791\nStop: Xi'an | Xi'an Xianyang International Airport | 2hr\nBaggage Allowance\nPlease check the baggage information at the bottom for more details.\nTaipei - Astana\nTaipei-Beijing, October 30\nDAMELI KASSYM\xa0(Adults)\nPersonal item\n1 piece per person\nCarry-on baggage\n1 piece per person, 5 kg each\nChecked baggage\n2 pieces per person, 23 kg each\nBeijing-Astana, October 31\nDAMELI KASSYM\xa0(Adults)\nPersonal item\n1 piece per person\nCarry-on baggage\n1 piece per person, 5 kg each\nChecked baggage\n2 pieces per person, 23 kg each\nImportant information\n• During various procedures in the airport, passengers must provide the valid ID used to purchase\ntheir ticket. Their boarding pass or itinerary may also be required.\n• Please note that tickets must be used in the sequence set out in the itinerary, otherwise airlines\nreserve the right to refuse carriage. Trip.com bears no responsibility if passengers are unable to\nboard a plane due to not complying with airline policies and regulations.\n• We make the suggestion to arrive at Taiwan Taoyuan International Airport at least 3h prior to\ndeparture to ensure you have enough time to check in.\nBaggage Information\n2"),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Itinerary.pdf', 'file_path': '..\\data\\pdf\\Itinerary.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}, page_content='Taipei-Beijing\n• Carry-on baggage: 1 piece per person, 5 kg each Dimensions of each piece cannot exceed\n55x40x20 cm\n• Checked baggage: 2 pieces per person, 23 kg each Dimensions (length + width + height) of each\npiece cannot exceed 158 cm\n• Personal item: 1 piece per person Please contact the airline for detailed baggage policies Must be\nplaced under the seat in front of you.\nBeijing-Astana\n• Carry-on baggage: 1 piece per person, 5 kg each Dimensions of each piece cannot exceed\n55x40x20 cm\n• Checked baggage: 2 pieces per person, 23 kg each Dimensions (length + width + height) of each\npiece cannot exceed 158 cm\n• Personal item: 1 piece per person Please contact the airline for detailed baggage policies Must be\nplaced under the seat in front of you.\n3'),
#  Document(metadata={'producer': 'mPDF 7.1.7', 'creator': '', 'creationdate': "20251026230508+05'00'", 'source': '..\\data\\pdf\\student_transcript (8).pdf', 'file_path': '..\\data\\pdf\\student_transcript (8).pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "20251026230508+05'00'", 'trapped': '', 'modDate': "20251026230508+05'00'", 'creationDate': "20251026230508+05'00'", 'page': 0}, page_content='NAZARBAYEV UNIVERSITY\nStudent Unoﬃcial Transcript\nDate: 26 October 2025\nStudent Name:\nKassym Dameli\nStudent ID:\n202174279\nSchool:\nSchool of Sciences and Humanities\nPrimary major:\nMathematics\nAdmission semester:\nFall 2023\nFall 2023\nCourse Code\nCourse Title\nGrade\nCredits\nECTS\nGrade\nPoints\nMATH 161\nCalculus I\nA\n8\n4\nPHYS 161\nPhysics I for Scientists and Engineers with\nLaboratory\nA-\n8\n3.67\nCSCI 115\nProgramming Fundamentals\nA\n8\n4\nWCS 150\nRhetoric and Composition\nB-\n6\n2.67\nSemester GPA: 3.65 Credits Enrolled: 30 Credits Earned: 30\nSpring 2024\nCourse Code\nCourse Title\nGrade\nCredits\nECTS\nGrade\nPoints\nMATH 162\nCalculus II\nA\n8\n4\nMATH 251\nDiscrete Mathematics\nB\n6\n3\nHST 100\nHistory of Kazakhstan\nB-\n6\n2.67\nMATH 273\nLinear Algebra with Applications\nA\n8\n4\nSemester GPA: 3.50 Credits Enrolled: 28 Credits Earned: 28\nSummer 2024\nCourse Code\nCourse Title\nGrade\nCredits\nECTS\nGrade\nPoints\nPHYS 162\nPhysics II for Scientists and Engineers with\nLaboratory\nA\n8\n4\nSemester GPA: 4.00 Credits Enrolled: 8 Credits Earned: 8\nFall 2024\nCourse Code\nCourse Title\nGrade\nCredits\nECTS\nGrade\nPoints\nMATH 263\nCalculus III\nA\n8\n4\nBUS 101\nCore Course in Business\nB+\n6\n3.33\nROBT 308\nIndustrial Automation\nA-\n6\n3.67\nMATH 321\nProbability\nA\n6\n4\nSemester GPA: 3.77 Credits Enrolled: 26 Credits Earned: 26'),
#  Document(metadata={'producer': 'mPDF 7.1.7', 'creator': '', 'creationdate': "20251026230508+05'00'", 'source': '..\\data\\pdf\\student_transcript (8).pdf', 'file_path': '..\\data\\pdf\\student_transcript (8).pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "20251026230508+05'00'", 'trapped': '', 'modDate': "20251026230508+05'00'", 'creationDate': "20251026230508+05'00'", 'page': 1}, page_content='Summer 2025\nSemester GPA: 0.0 Credits Enrolled: 0 Credits Earned: 0\nOverall\nGPA: 3.67\nCredits Enrolled: 92 Credits Earned: 92\n* - not included in calculation of the GPA or in earned credits.\n------------------------END OF TRANSCRIPT------------------------'),
#  Document(metadata={'producer': 'Skia/PDF m140', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36', 'creationdate': '2025-10-03T21:21:34+00:00', 'source': '..\\data\\pdf\\Trip.com.pdf', 'file_path': '..\\data\\pdf\\Trip.com.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': 'Trip.com', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-10-03T21:21:34+00:00', 'trapped': '', 'modDate': "D:20251003212134+00'00'", 'creationDate': "D:20251003212134+00'00'", 'page': 0}, page_content="Ticket(s) issued \ue6e1\nPlease arrive at the airport at least 3 hours before departure to ensure you have sufficient time to check in\nBooking No.\xa01688893809231567 \nPIN: 5254\n[Penalties for Skipping a Flight in Your Booking] According to the airline's policy, skipping flights is not permitted for some flights in your booking. If you skip a flight that is\nsubject to these restrictions, you may be denied boarding for subsequent flights or charged additional fees.View Details\n[Seat(s) reserved] Please check in on the airline website or at the airport counter before departure\nStay informed and never miss a flight! Download our mobile app for instant updates.\nFlight Details\nAll times are in local time\nFlight Delayed or Canceled?\n\ue619Flyer Exclusive\nYou have a 14-hour nighttime transfer – book a hotel near the airport to get in some shut-eye!\n\ue606Up to 25% off\nAdditional discount of up to 5,633 KZT\n\ue606\n if your flight is rescheduled\nClaim now\ue609\nYour Add-ons\nVIP Lounge\nRelax before your departure\nAdd\nAdditional Baggage Allowance\nFrom 64,426.00 KZT/23 kg\nAdd\nAirline booking reference (PNR): MJX858\nE-ticket number: 999-7379002837\nOne-way\nThu, Oct 30\nTaipei\xa0-\xa0Astana\n3h 35m\nTPE Taipei Taiwan Taoyuan Intl. T2\n18:45\nPEK Beijing Capital Intl. T3\n22:20\n\ue68b\nAir China CA190 \ue659\nEconomy class\nAirbus A321 (Mid-sized)\nTransfer in Beijing 14h 40m\n\ue60b\n\ue60d\nOvernight transfer\nNo need to collect & re-check baggage\n10h 20m\nOct 31\nOct 31\nPEK Beijing Capital Intl. T3\n13:00\nStop in Xi'an\xa0\xa02h 0m No need to collect & re-check baggage\nNQZ Astana Nursultan Nazarbayev Intl. T1\n20:20\nAir China CA791 \ue659\nEconomy class\nBoeing 737MAX8 (Mid-sized)\nFree Cancellation\nPromo code\n2 available\nDelayed Baggage Protection\nPut the Final Touches on Your Trip\nPassenger Information\nManage flight bookings easily with the Trip.com app\n4.8/5\n4.5/5\n\ue787\ue787\ue787\ue787\ue787\n\ue787\ue787\ue787\ue787\ue787"),
#  Document(metadata={'producer': 'Skia/PDF m140', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36', 'creationdate': '2025-10-03T21:21:34+00:00', 'source': '..\\data\\pdf\\Trip.com.pdf', 'file_path': '..\\data\\pdf\\Trip.com.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': 'Trip.com', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-10-03T21:21:34+00:00', 'trapped': '', 'modDate': "D:20251003212134+00'00'", 'creationDate': "D:20251003212134+00'00'", 'page': 1}, page_content="Manage My Booking\n\ue616\nCancel Booking\n\ue614\nChange Booking\n\ue665\nView/update passenger info\n\ue699\nView/update contact info\n\ue613\nCheck-in & Seats\n\ue611\nGet Itinerary\n\ue612\nGet E-receipt\nNo hidden fees - total price includes all fees\nand charges\n1:\xa0DAMELI (First name) KASSYM (Last name)\nID type:\xa0\nPassport\nID number:\xa0\nN17325869\nNationality:\xa0\nKazakhstan\nGender:\xa0\nFemale | Adult\nDate of birth:\xa0\nMay 19, 2005\nFrequent flyer programs\n\ue69eAdd\nThe exact number of miles/points earned depends on the airline's policies\nContact Information\nDAMELI KASSYM\nPhone:\xa0\n+886 976256932\nEmail:\xa0\ndameli.kassym@nu.edu.kz\nTotal paid\n183,504.00 KZT\nView price details\n\ue604\nManage flight bookings easily with the Trip.com app\n4.8/5\n4.5/5\n\ue787\ue787\ue787\ue787\ue787\n\ue787\ue787\ue787\ue787\ue787")]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
